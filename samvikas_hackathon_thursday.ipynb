# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanyadasari/samVikas/blob/main/samvikas_hackathon_thursday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot_2samples
from statsmodels.graphics.gofplots import qqplot
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objs as po
import plotly.offline as py 
from sklearn import tree
#from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.tree import export_graphviz
from sklearn.tree import plot_tree
import plotly.offline as py 
py.init_notebook_mode(connected=True) 
import plotly.graph_objs as go 
import plotly.tools as tls 
import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#df = pd.read_csv('samvikas_data.csv')

# %%
df = pd.read_csv('Samvikas_data_record.csv')

# %%
df
# Out:
#            Name  Months  Height  ... Feature 6       Location  Unnamed: 12
# 0         pooja       3      50  ...         0  DIBANG VALLEY          NaN
# 1         nisha       4      45  ...         0    WEST KAMENG          NaN
# 2         bimla       5      58  ...         0    EAST KAMENG          NaN
# 3          rada       3      49  ...         0  TAWANG(W KAME          NaN
# 4          maya       4      52  ...         0   KURUNG KUMEY          NaN
# ..          ...     ...     ...  ...       ...            ...          ...
# 99       leela        3      49  ...         0        KAITHAL          NaN
# 100        isha       6      52  ...         0     TARN TARAN          NaN
# 101     gulshan       7      55  ...         0       BILASPUR          NaN
# 102  priya jain       4      70  ...         0         CHAMBA          NaN
# 103       pooja       9      66  ...         0         KANGRA          NaN
#
# [104 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Months', 'Height', 'Gender', 'Contact', 'Feature 1',
#        'Feature 2', 'Feature 3', 'Feature 4', 'Feature 5', 'Feature 6',
#        'Location', 'Unnamed: 12'],
#       dtype='object')

# %%
df.rename(columns={'Unnamed: 12': 'Score'}, inplace=True)

# %%
print(df.head())
# Out:
#     Name  Months  Height Gender  ...  Feature 5  Feature 6       Location  Score
# 0  pooja       3      50      f  ...          0          0  DIBANG VALLEY    NaN
# 1  nisha       4      45      f  ...          0          0    WEST KAMENG    NaN
# 2  bimla       5      58      f  ...          0          0    EAST KAMENG    NaN
# 3   rada       3      49      f  ...          0          0  TAWANG(W KAME    NaN
# 4   maya       4      52      f  ...          0          0   KURUNG KUMEY    NaN
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (104, 12)

# %%
df1 = df.fillna(0)
df1
# Out:
#            Name  Months  Height  ... Feature 6       Location  Score
# 0         pooja       3      50  ...         0  DIBANG VALLEY    0.0
# 1         nisha       4      45  ...         0    WEST KAMENG    0.0
# 2         bimla       5      58  ...         0    EAST KAMENG    0.0
# 3          rada       3      49  ...         0  TAWANG(W KAME    0.0
# 4          maya       4      52  ...         0   KURUNG KUMEY    0.0
# ..          ...     ...     ...  ...       ...            ...    ...
# 99       leela        3      49  ...         0        KAITHAL    0.0
# 100        isha       6      52  ...         0     TARN TARAN    0.0
# 101     gulshan       7      55  ...         0       BILASPUR    0.0
# 102  priya jain       4      70  ...         0         CHAMBA    0.0
# 103       pooja       9      66  ...         0         KANGRA    0.0
#
# [104 rows x 13 columns]

# %%
df2 = df1[df1.columns.drop(['Height'])]

# %%
#df2 = df1.fillna(0)
#df2
#df2['Gender'].astype(str)
# Out:
# 0     M
# 2     F
# 3     F
# 4     F
# 5     M
# 6     M
# 7     M
# 8     F
# 9     M
# 10    M
# 11    F
# 12    F
# 13    M
# 14    F
# 15    M
# 16    F
# 17    F
# 18    M
# 19    F
# 20    M
# Name: Gender, dtype: object

# %%
#visualization 
df2['Months'].hist()

# %%
#visualization 

df2
# Out:
#            Name  Months Gender  ...  Feature 6       Location  Score
# 0         pooja       3      f  ...          0  DIBANG VALLEY    0.0
# 1         nisha       4      f  ...          0    WEST KAMENG    0.0
# 2         bimla       5      f  ...          0    EAST KAMENG    0.0
# 3          rada       3      f  ...          0  TAWANG(W KAME    0.0
# 4          maya       4      f  ...          0   KURUNG KUMEY    0.0
# ..          ...     ...    ...  ...        ...            ...    ...
# 99       leela        3      f  ...          0        KAITHAL    0.0
# 100        isha       6      f  ...          0     TARN TARAN    0.0
# 101     gulshan       7      f  ...          0       BILASPUR    0.0
# 102  priya jain       4      f  ...          0         CHAMBA    0.0
# 103       pooja       9      f  ...          0         KANGRA    0.0
#
# [104 rows x 12 columns]

# %%
df2.dtypes
# Out:
# Name          object
# Months         int64
# Gender        object
# Contact        int64
# Feature 1      int64
# Feature 2    float64
# Feature 3    float64
# Feature 4    float64
# Feature 5    float64
# Feature 6    float64
# Location      object
# Remarks      float64
# dtype: object

# %%
#visualization 
df2['Gender'].hist()

# %%
df2['Score'] = (df2['Feature 1'] + df2['Feature 2']+ df2['Feature 3'] + df2['Feature 4']+ df2['Feature 5'] + df2['Feature 6'])

# %%
for index, row in df2.iterrows():
  print(row['Score'])
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
df2
# Out:
#            Name  Months Gender  ...  Feature 6       Location  Score
# 0         pooja       3      f  ...          0  DIBANG VALLEY    NaN
# 1         nisha       4      f  ...          0    WEST KAMENG    NaN
# 2         bimla       5      f  ...          0    EAST KAMENG    NaN
# 3          rada       3      f  ...          0  TAWANG(W KAME    NaN
# 4          maya       4      f  ...          0   KURUNG KUMEY    NaN
# ..          ...     ...    ...  ...        ...            ...    ...
# 99       leela        3      f  ...          0        KAITHAL    NaN
# 100        isha       6      f  ...          0     TARN TARAN    NaN
# 101     gulshan       7      f  ...          0       BILASPUR    NaN
# 102  priya jain       4      f  ...          0         CHAMBA    NaN
# 103       pooja       9      f  ...          0         KANGRA    NaN
#
# [104 rows x 12 columns]

# %%
ax1 = df2.plot.scatter(x ='Months',y ='Score')
ax1

# %%
#condition to group the data 

df2['Zone'] = 'Green'
# add all the conditions three zones and mark that points on the graph and export the html to powerBI if possible
# Out:
#            Name  Months Gender  ...       Location  Score   Zone
# 0         pooja       3      f  ...  DIBANG VALLEY    NaN  Green
# 1         nisha       4      f  ...    WEST KAMENG    NaN  Green
# 2         bimla       5      f  ...    EAST KAMENG    NaN  Green
# 3          rada       3      f  ...  TAWANG(W KAME    NaN  Green
# 4          maya       4      f  ...   KURUNG KUMEY    NaN  Green
# ..          ...     ...    ...  ...            ...    ...    ...
# 99       leela        3      f  ...        KAITHAL    NaN  Green
# 100        isha       6      f  ...     TARN TARAN    NaN  Green
# 101     gulshan       7      f  ...       BILASPUR    NaN  Green
# 102  priya jain       4      f  ...         CHAMBA    NaN  Green
# 103       pooja       9      f  ...         KANGRA    NaN  Green
#
# [104 rows x 13 columns]

# %%
from bokeh.io import output_file
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool
output_notebook()
# My x-y coordinate data

source = ColumnDataSource(data=dict(
x = list(df2['Months']),
y = list(df2['Score']),
name = list(df2['Name']),
gender = list(df2['Gender']),
location = list(list(df2['Location']))
))

tooltips = [
           ("name","@name"),
            ("gender","@gender"),
            ("location","@location"),
            ("(x,y)", "($x, $y)"),     
           ]


# Output the visualization directly in the notebook
output_file('first_glyphs.html', title='First Glyphs')

# Create a figure with no toolbar and axis ranges of [0,3]
fig = figure(title='SamVikas',
             plot_height=500, plot_width=800,
             x_range=(2, 21), y_range=(-1, 6),
             toolbar_location=None,tooltips=tooltips)

# Draw the coordinates as circles
fig.circle('x','y', color='green', size= 10, alpha=0.5,source=source )
# Out:
# GlyphRenderer(id='3369', ...)

# %%
# Show plot

fig.add_tools(HoverTool(tooltips=tooltips))

show(fig)
# Add the HoverTool to the figure
# Out:
#   <div class="bk-root" id="a913903a-ae7c-4ac0-b184-df452b678e34" data-root-id="3331"></div>
